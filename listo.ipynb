# %% [markdown]
# # EI2001: Ciencia de Datos en Astronomía
# **Profesores:** Pía Cortés, Daniela Barrientos, Matías Suazo, Matías Mattamala
#
# ## Minitarea 1: Repaso de python
#
# **Objetivos:**
# 1. Repasar conceptos básicos y "soltar la mano" con Python
# 2. Comprender el uso de Google Colab
# 3. Integración de Google Colab con GitHub
#
# **Instrucciones:**
# 0. Lean cuidadosamente todo lo que viene ahora
# 1. Para hacer esta tarea tienen que hacer un **fork** del repositorio en sus cuentas de GitHub.
# 2. Luego deben habilitar sus cuentas de [Google Colab](https://colab.research.google.com) (cuenta Google requerida)
# 3. Abrir Google Colab y seleccionar "abrir un archivo desde GitHub". Deben seleccionar su cuenta Github y escoger el repositorio que corresponde al fork que hicieron.
# 4. Si todo sale bien, debería abrirse una copia de este notebook en su cuenta de Google Colab.
# 5. Se adjuntan 6 mini actividades a completar. TODAS son necesarias y deben completar lo que se va pidiendo.
# 6. Cada vez que completen un ítem, deben guardar un avance en su fork de GitHub, de modo de **respaldar cada avance significativo**. Usen comentarios coherentes con cada respaldo "Sección 1 completa", "Tarea terminada", no solamente el que pone por defecto.

# %% [markdown]
# ## 1. Variables
#
# Declara la variable `AU` (por Unidad Astronómica en inglés) y asignale su valor correspondiente en kilómetros.
# Declara la variable `radio_tierra` y también asígnale su valor en kilómetros.

# %%
AU=149597870.691
radio_tierra=6371

# %% [markdown]
# ## 2. Listas
# Declara las siguientes listas, buscando la información correspondiente en internet:
#
# 1. `planetas` con strings correspondientes a los planetas del sistema solar
# 2. `radio_planetas`, con numeros decimales correspondientes a los radios (o radio medio) de los planetas (en kms), en el mismo orden que los escribiste anteriormente
# 3. `distancia_planetas`, con números decimales correspondientes a la distancia de cada planeta al sol (en kms)
#
# Por último, también declara las variable `num_planetas`, `num_radios` y `num_distancias` con el número de elementos de cada lista, obtenido usando funciones de Python.
#
# Usa estos números para guardar en la variable `checksum` un valor booleano que indique si los tres valores son iguales, y printealo en pantalla de forma tal que diga _"Checksum: Todas las listas tienen el mismo tamaño"_ si el resultado es `True` y _"Checksum: ERROR: NO todas las listas tienen el mismo tamaño!"_, si no coinciden.
#
#
#
# (Dato freak: checksum es un tipo de prueba que se realiza al transferir datos por internet para comprobar que los datos recibidos/enviados tienen el mismo tamaño que deberían. [Más información](https://es.wikipedia.org/wiki/Suma_de_verificaci%C3%B3n))

# %%
planetas=["mercurio","venus","tierra","marte","jupiter","saturno","urano","neptuno"]
radio_planeta=[2439.7,6051.8,6371,3389.5,69911,58232,25362,24622]
distancia_planetas=[57909175,108208930,149597870,227936640,778412010,1426725400,2870972200,4498252900]
num_planetas=len(planetas)
num_radios=len(radio_planeta)
num_distancias=len(distancia_planetas)
def validar(a,b,c):
  if a==b and b==c:
    checksum=True
  else:
    checksum=False
  if checksum==True:
    print ("Checksum: Todas las listas tienen el mismo tamaño")
  else: 
    print("Checksum: ERROR: NO todas las listas tienen el mismo tamaño!")
validar(num_planetas,num_radios,num_distancias)
# Out:
# Checksum: Todas las listas tienen el mismo tamaño

# %% [markdown]
# ## 3. Clases
# Crea una clase `Planeta` que:
#
# - Tenga las variables internas `nombre`, `radio` y `distancia`, donde el primero es el nombre del planeta, el segundo su radio y el tercero la distancia del planeta al Sol.
# - El constructor de la clase debe recibir estos tres parámetros al crear un objeto `Planeta`.
# - Adicionalmente, la clase debe poseer una función `info` que retorne un `string` con el siguiente texto : _NombreDelPlaneta, radio=9999 [km], distancia=9999 [km]_, donde el nombre del planeta y el radio deben obtenerse de las variables internas de la clase.
#
#
# Prueba la clase planeta creando el planeta `vulcano` usando los siguientes datos del ficticio planeta [Vulcano](https://es.wikipedia.org/wiki/Vulcano_(planeta_hipot%C3%A9tico):
# - **Nombre:** Vulcano
# - **Radio:** 90 km
# - **Distancia al sol:** 15,000,000 [km]
#
# y printea el `string` que entrega la función `info`.

# %%
# Define acá la clase Planeta
class Planeta:
  def __init__(self,nombre,radio,distancia):
    self.nombre=nombre
    self.radio=radio
    self.distancia=distancia

  def info(self):
    return ("Nombre:" + self.nombre +", radio="+ str(self.radio) +"[km], distancia="+ str(self.distancia)+ "[km]" )


# aca creamos una instancia de vulcano como Planeta
vulcano = Planeta("vulcano",90,15000000)
vulcano.info()
# Out:
# 'Nombre:vulcano, radio=90[km], distancia=15000000[km]'

# %% [markdown]
# ## 4. Diccionarios
# Usando las listas de planetas, radios y distancias crea un diccionario `dict_planetas` en que cada _llave_ sea el nombre del planeta, y el valor asignado sea un objeto `Planeta` que se cree usando la información respectiva de cada uno.
#
# Prueba que todo esté correcto printeando la información de todos los planetas.

# %%
dict_planetas={}
def rellenardict(pla,rad,dist,i=0):
  while i<=(len(pla)-1):
    
    dict_planetas[str(pla[i])]=Planeta(str(pla[i]),rad[i],dist[i])
    i=i+1
    
rellenardict(planetas,radio_planeta,distancia_planetas)

for key in dict_planetas:
    print (dict_planetas[key].info())
# Out:
# Nombre:mercurio, radio=2439.7[km], distancia=57909175[km]
# Nombre:venus, radio=6051.8[km], distancia=108208930[km]
# Nombre:tierra, radio=6371[km], distancia=149597870[km]
# Nombre:marte, radio=3389.5[km], distancia=227936640[km]
# Nombre:jupiter, radio=69911[km], distancia=778412010[km]
# Nombre:saturno, radio=58232[km], distancia=1426725400[km]
# Nombre:urano, radio=25362[km], distancia=2870972200[km]
# Nombre:neptuno, radio=24622[km], distancia=4498252900[km]

# %% [markdown]
# ## 5. Graficos en Python
# _(Este es un spoiler de la próxima clase)_
#
# Grafica todos los planetas alineados, considerando que el sol está en la posición (0,0). Te servirán las siguientes funciones de Python, usando el _Planeta Vulcano_  que creaste anteriormente como ejemplo.
#
# **Usa el bloque de abajo sólo como referencia, tu código deberás escribirlo en el bloque de abajo**

# %%
# Matplotlib es una libreria que sirve para ahcer graficos como en MATLAB
import matplotlib.pyplot as plt


# La parte de abajo usa las funciones de matplotlib para graficar un planeta
# Primero creamos una figura donde pondremos los objetos
fig1 = plt.figure()
# Despues creamos el dibujo del planeta como un gráfico de un sólo punto, usando la función PLOT
# Primero la coordenada X
# el segundo valor es la coordenada Y (usamos 0 por simplicidad)
# el tercer valor indica que en vez de hacer un gráfico de líneas, usaremos puntos
# el ultimo valor, markersize, indica el tamaño del que queremos dibujar el punto
plt.plot(vulcano.distancia, 0, 'o', markersize=vulcano.radio)

# La función TEXT nos permite poner un texto
# Primero va la coordenada X
# Segundo la coordenada Y
# Tercera es el texto
# Cuarto es la orientación del texto
# Finalmente el tamaño del texto
plt.text(vulcano.distancia, -0.015, vulcano.info(), rotation=-10, size=12)


# Por ultimo ponemos la información que no puede faltar nunca en un gráfico: las etiquetas y titulo
plt.xlabel('Distancia al sol [kms])')
plt.ylabel('Distancia al sol [kms]')
plt.title('Posición de los planetas')

# %% [markdown]
# **Pon tu gráfico de los planetas acá abajo**
#
# Hint 1: Si tienes problemas para visualizar los planetas, prueba normalizando los radios de los planetas por una distancia "conveniente" como las que buscaste en la primera parte. Lo mismo para las distancias de cada planeta al sol.

# %%
import matplotlib.pyplot as plt

plt.plot(dict_planetas["mercurio"].distancia/AU , 0,'o',markersize=dict_planetas["mercurio"].radio/radio_tierra)
plt.plot(dict_planetas["venus"].distancia/AU, 0,'o',markersize=dict_planetas["venus"].radio/radio_tierra)
plt.plot(dict_planetas["tierra"].distancia/AU, 0,'o',markersize=dict_planetas["tierra"].radio/radio_tierra)
plt.plot(dict_planetas["marte"].distancia/AU, 0,'o',markersize=dict_planetas["marte"].radio/radio_tierra)
plt.plot(dict_planetas["jupiter"].distancia/AU, 0,'o',markersize=dict_planetas["jupiter"].radio/radio_tierra)
plt.plot(dict_planetas["saturno"].distancia/AU, 0,'o',markersize=dict_planetas["saturno"].radio/radio_tierra)
plt.plot(dict_planetas["urano"].distancia/AU, 0,'o',markersize=dict_planetas["urano"].radio/radio_tierra)
plt.plot(dict_planetas["neptuno"].distancia/AU, 0,'o',markersize=dict_planetas["neptuno"].radio/radio_tierra)


plt.text(dict_planetas["mercurio"].distancia/AU, -0.015,dict_planetas["mercurio"].info(),rotation=-90, size=12)
plt.text(dict_planetas["venus"].distancia/AU, -0.015,dict_planetas["venus"].info(),rotation=-80, size=12)
plt.text(dict_planetas["tierra"].distancia/AU, -0.015,dict_planetas["tierra"].info(),rotation=-70, size=12)
plt.text(dict_planetas["marte"].distancia/AU, -0.015,dict_planetas["marte"].info(),rotation=-60, size=12)
plt.text(dict_planetas["jupiter"].distancia/AU, -0.015,dict_planetas["jupiter"].info(),rotation=-50, size=12)
plt.text(dict_planetas["saturno"].distancia/AU, -0.015,dict_planetas["saturno"].info(),rotation=-40, size=12)
plt.text(dict_planetas["urano"].distancia/AU, -0.015,dict_planetas["urano"].info(),rotation=-30, size=12)
plt.text(dict_planetas["neptuno"].distancia/AU, -0.015,dict_planetas["neptuno"].info(),rotation=-20, size=12)

plt.xlabel('Distancia al sol [kms])')
plt.ylabel('Distancia al sol [kms]')
plt.title('Posición de los planetas')
# Out:
# Text(0.5, 1.0, 'Posición de los planetas')

# %% [markdown]
# ## 6. Bonus: Ponte creativ@
# En esta última parte te pedimos que hagas algún aporte entretenido al trabajo anterior. No olvides comentar adecuadamente el código que generes, ya que tiene que quedar claro qué estas haciendo.
#
# Algunas ideas incluyen colorear los planetas con el color más parecido que se pueda, o cambiar sus posiciones espaciales, agregar el sol, entre otras cosas.
#
#
# Este es tu momento de brillar.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse 
dict_planetas["sol"]=Planeta("sol", 695510, 0)
plt.plot(dict_planetas["sol"].distancia/AU, 0,'o',markersize=dict_planetas["sol"].radio/radio_tierra, color="yellow")
plt.plot(dict_planetas["mercurio"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["mercurio"].radio/radio_tierra, color="grey")
plt.plot(dict_planetas["venus"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["venus"].radio/radio_tierra,color="gold")
plt.plot(dict_planetas["tierra"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["tierra"].radio/radio_tierra,color="mediumblue")
plt.plot(dict_planetas["marte"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["marte"].radio/radio_tierra,color="red")
plt.plot(dict_planetas["jupiter"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["jupiter"].radio/radio_tierra, color="lightsalmon")
plt.plot(dict_planetas["saturno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["saturno"].radio/radio_tierra,color="peru")
plt.plot(dict_planetas["urano"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["urano"].radio/radio_tierra,color="paleturquoise")
plt.plot(dict_planetas["neptuno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, 0,'o',markersize=dict_planetas["neptuno"].radio/radio_tierra,color="b")


plt.text(dict_planetas["mercurio"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["mercurio"].info()+", numero de lunas=0",rotation=-90, size=12, color="grey")
plt.text(dict_planetas["venus"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["venus"].info()+", numero de lunas=0",rotation=-80, size=12,color="gold")
plt.text(dict_planetas["tierra"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["tierra"].info()+", numero de lunas=1",rotation=-70, size=12,color="mediumblue")
plt.text(dict_planetas["marte"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["marte"].info()+", numero de lunas=2",rotation=-60, size=12,color="red")
plt.text(dict_planetas["jupiter"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["jupiter"].info()+", numero de lunas=67",rotation=-50, size=12, color="lightsalmon")
plt.text(dict_planetas["saturno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["saturno"].info()+", numero de lunas=62",rotation=-40, size=12,color="peru")
plt.text(dict_planetas["urano"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["urano"].info()+", numero de lunas=27",rotation=-30, size=12,color="turquoise")
plt.text(dict_planetas["neptuno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra, -0.015,dict_planetas["neptuno"].info()+", numero de lunas=14",rotation=-20, size=12,color="b")

plt.xlabel('Distancia al sol [kms])')
plt.ylabel('Distancia al sol [kms]')
plt.title('Posición de los planetas')


#dibujo de las orbitas de los planetas 

ax = plt.gca() 

ellipse = Ellipse(xy=(0,0), width=(dict_planetas["mercurio"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.08, 
         edgecolor='grey', fc='None', lw=0.2) 
ellipse1 = Ellipse(xy=(0,0), width=(dict_planetas["venus"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.09, 
         edgecolor='gold', fc='None', lw=0.2) 
ellipse2 = Ellipse(xy=(0,0), width=(dict_planetas["tierra"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.1, 
         edgecolor='mediumblue', fc='None', lw=0.2) 
ellipse3 = Ellipse(xy=(0,0), width=(dict_planetas["marte"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.11, 
         edgecolor='red', fc='None', lw=0.2) 
ellipse4 = Ellipse(xy=(0,0), width=(dict_planetas["jupiter"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.12, 
         edgecolor='lightsalmon', fc='None', lw=0.2) 
ellipse5 = Ellipse(xy=(0,0), width=(dict_planetas["saturno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.13, 
         edgecolor='peru', fc='None', lw=0.2) 
ellipse6 = Ellipse(xy=(0,0), width=(dict_planetas["urano"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.14, 
         edgecolor='turquoise', fc='None', lw=0.2) 
ellipse7 = Ellipse(xy=(0,0), width=(dict_planetas["neptuno"].distancia/AU+dict_planetas["sol"].radio/radio_tierra)*2, height=0.15, 
         edgecolor='b', fc='None', lw=0.2) 
ax.add_patch(ellipse) 
ax.add_patch(ellipse1)
ax.add_patch(ellipse2)
ax.add_patch(ellipse3)
ax.add_patch(ellipse4)
ax.add_patch(ellipse5)
ax.add_patch(ellipse6)
ax.add_patch(ellipse7)
#intente hacer que se movieran en las orbitas segun su periodo, sin embargo fracase miserablemente en el intento :(
